# %% [markdown]
# <a href="https://colab.research.google.com/github/leticiamchd/Notebooks/blob/main/disney_data_show%26movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise dos Dados da Disney+
#
# Este caderno vai ser utilizado para tentar resolver uma dúvida que tive durante a Live da Staart, do dia 19/05 com a Thaissa Candella e Rafael Yamagata. Além de servir como exercício, já que quero resolver essa questão apenas com os conhecimentos que adquiri até agora.
#
# **Qual a dúvida?** A correlação entre os gêneros e as notas do IMDB
#
# ***Para tentar chegar a resposta, adotei alguns critérios de inclusão:***
# 1. Apenas filmes
# 2. Ter sido pontuado no IMDB
# 3. Gêneros precisam estar descritos
#
# *Os que não respeitaram os 3 critérios, a linha inteira foi removida.*
#
# ---
#
# Dataset original: https://www.kaggle.com/datasets/victorsoeiro/disney-tv-shows-and-movies
#
# ---
#
# ## Limpeza dos Dados
#
# 1. Excluídos as seguintes colunas por não possuírem utilidade para esta análise: *id ; description ; age_certification ; production_countries ; seasons ; imdb_id ; tmdb_popularity ; tmdb_score*
# 2. Filtrado as colunas para a procura de espaços em branco, e posteriromente excluídas essas linhas
# 3. Criado novas colunas para separar as variáveis de gênero, já que estavam todas reunidas numa mesma coluna. Essa separação foi feita através da função REGEXEXTRAC, extraindo o nome exato do gênero. Provavelmente deve haver uma maneira mais fácil de realizar esse desmembramento, porém foi dessa maneira que consegui realizar, já que tente com a função SPLIT e MID, e não consegui o resultado desejado.
# 4. Foi criado novas colunas para mudar o tipo de variável da coluna imdb_score, já que as variáveis estavam como se fossem data.
#
# Dataset após limpeza: https://docs.google.com/spreadsheets/d/1lgrPR2MERMXfHwpaUj45MnkOHIFSIp9y_tQ3akAixWw/edit?usp=sharing
#
# ---
#
# ## Análise dos Dados
#
# 1. Para chegar na relação entre gêneros dos filmes e notas do IMDB, pensei em descobrir a média da nota de cada gênero. Como o há a possibilidade de vários gêneros em apenas um filme, a função REGEXEXTRAC ajudou a mapear em quais filmes um determinado gênero aparecia, e assim, ao usar a função AVERAGEIF, conseguir saber a média das notas do IMDB apenas quando um gênero espeífico estava presente
#
# No final, acabei chegando a resposta que eu queria encontrar, apenas utilizando o spreadsheets. Como a intenção também é utilizar aqui para poder praticar, irei tentar realizar essa análise aqui. Porém mantive no arquivo csv, a análise completa.

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d498c2e6-df45-424e-a354-d5551ac9d0f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d498c2e6-df45-424e-a354-d5551ac9d0f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving disney_data_cleaned - titles.csv to disney_data_cleaned - titles.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['disney_data_cleaned - titles.csv'])) 
print(df)
# Out:
#                                       title   type  release_year  runtime  \
# 0                                  Fantasia  MOVIE          1940      120
# 1           Snow White and the Seven Dwarfs  MOVIE          1937       83
# 2                                 Pinocchio  MOVIE          1940       88
# 3                                     Bambi  MOVIE          1942       70
# 4                           Treasure Island  MOVIE          1950       96
# ..                                      ...    ...           ...      ...
# 738                             Shark Gangs  MOVIE          2021       44
# 739                            Own the Room  MOVIE          2021       91
# 740  Built for Mars: The Perseverance Rover  MOVIE          2021       88
# 741           Killer Shark vs. Killer Whale  MOVIE          2021       44
# 742                   Far From Raven's Home  MOVIE          2021       11
#
#     reality  documentation  music western  family  fantasy  ... european  \
# ...

# %%
df.head()
# Out:
#                              title   type  release_year  runtime reality  \
# 0                         Fantasia  MOVIE          1940      120     NaN
# 1  Snow White and the Seven Dwarfs  MOVIE          1937       83     NaN
# 2                        Pinocchio  MOVIE          1940       88     NaN
# 3                            Bambi  MOVIE          1942       70     NaN
# 4                  Treasure Island  MOVIE          1950       96     NaN
#
#   documentation  music western  family  fantasy  ... european horror  \
# 0           NaN  music     NaN  family  fantasy  ...      NaN    NaN
# 1           NaN    NaN     NaN  family  fantasy  ...      NaN    NaN
# 2           NaN    NaN     NaN  family  fantasy  ...      NaN    NaN
# 3           NaN    NaN     NaN  family      NaN  ...      NaN    NaN
# 4           NaN    NaN     NaN  family      NaN  ...      NaN    NaN
#
#    Unnamed: 21                                             genres imdb_votes  \
# ...

# %%
df.head()
# Out:
#                              title   type  release_year  runtime reality  \
# 0                         Fantasia  MOVIE          1940      120     NaN
# 1  Snow White and the Seven Dwarfs  MOVIE          1937       83     NaN
# 2                        Pinocchio  MOVIE          1940       88     NaN
# 3                            Bambi  MOVIE          1942       70     NaN
# 4                  Treasure Island  MOVIE          1950       96     NaN
#
#   documentation  music western  family  fantasy  ... european horror  \
# 0           NaN  music     NaN  family  fantasy  ...      NaN    NaN
# 1           NaN    NaN     NaN  family  fantasy  ...      NaN    NaN
# 2           NaN    NaN     NaN  family  fantasy  ...      NaN    NaN
# 3           NaN    NaN     NaN  family      NaN  ...      NaN    NaN
# 4           NaN    NaN     NaN  family      NaN  ...      NaN    NaN
#
#    Unnamed: 21                                             genres imdb_votes  \
# ...

# %%
df.reality.head(10)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# Name: reality, dtype: object
